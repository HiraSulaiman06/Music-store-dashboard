# %%
import pandas as pd

# %%
df= pd.read_csv("data-music-store-invoice.csv")

# %%
df.head()
# Out:
#    invoice_id  customer_id   invoice_date   billing_address billing_city  \
# 0           1           18  1/3/2017 0:00      627 Broadway     New York
# 1           2           30  1/3/2017 0:00  230 Elgin Street       Ottawa
# 2           3           40  1/5/2017 0:00    8, Rue Hanovre        Paris
# 3           4           18  1/6/2017 0:00      627 Broadway     New York
# 4           5           27  1/7/2017 0:00   1033 N Park Ave       Tucson
#
#   billing_state billing_country billing_postal  total
# 0            NY             USA     10012-2612  15.84
# 1            ON          Canada        K2P 1L7   9.90
# 2           NaN          France          75002   1.98
# 3            NY             USA     10012-2612   7.92
# 4            AZ             USA          85719  16.83

# %%
df.shape
# Out:
# (614, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of      invoice_id  customer_id     invoice_date       billing_address  \
# 0             1           18    1/3/2017 0:00          627 Broadway
# 1             2           30    1/3/2017 0:00      230 Elgin Street
# 2             3           40    1/5/2017 0:00        8, Rue Hanovre
# 3             4           18    1/6/2017 0:00          627 Broadway
# 4             5           27    1/7/2017 0:00       1033 N Park Ave
# ..          ...          ...              ...                   ...
# 609         610           55  12/21/2020 0:00     421 Bourke Street
# 610         611           52  12/27/2020 0:00     202 Hoxton Street
# 611         612           33  12/27/2020 0:00        5112 48 Street
# 612         613           20  12/29/2020 0:00  541 Del Medio Avenue
# 613         614           53  12/30/2020 0:00          113 Lupus St
#
#       billing_city billing_state billing_country billing_postal  total
# 0         New York            NY             USA     10012-2612  15.84
# 1           Ottawa            ON          Canada        K2P 1L7   9.90
# 2            Paris           NaN          France          75002   1.98
# 3         New York            NY             USA     10012-2612   7.92
# 4           Tucson            AZ             USA          85719  16.83
# ..             ...           ...             ...            ...    ...
# 609         Sidney           NSW       Australia           2010   6.93
# 610         London           NaN  United Kingdom         N1 5LH   1.98
# 611    Yellowknife            NT          Canada        X1A 1N6  11.88
# 612  Mountain View            CA             USA      94040-111   8.91
# 613         London           NaN  United Kingdom       SW1V 3EN  12.87
#
# [614 rows x 9 columns]>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       614 non-null    int64
#  1   customer_id      614 non-null    int64
#  2   invoice_date     614 non-null    str
#  3   billing_address  614 non-null    str
#  4   billing_city     614 non-null    str
#  5   billing_state    310 non-null    str
#  6   billing_country  614 non-null    str
#  7   billing_postal   559 non-null    str
#  8   total            614 non-null    float64
# dtypes: float64(1), int64(2), str(6)
# memory usage: 75.3 KB

# %%
df.columns
# Out:
# Index(['invoice_id', 'customer_id', 'invoice_date', 'billing_address',
#        'billing_city', 'billing_state', 'billing_country', 'billing_postal',
#        'total'],
#       dtype='str')

# %%
df["invoice_date"] = pd.to_datetime(df["invoice_date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       614 non-null    int64
#  1   customer_id      614 non-null    int64
#  2   invoice_date     614 non-null    datetime64[us]
#  3   billing_address  614 non-null    str
#  4   billing_city     614 non-null    str
#  5   billing_state    310 non-null    str
#  6   billing_country  614 non-null    str
#  7   billing_postal   559 non-null    str
#  8   total            614 non-null    float64
# dtypes: datetime64[us](1), float64(1), int64(2), str(5)
# memory usage: 66.9 KB

# %%
df["month_year"] = (df["invoice_date"].dt.to_period("M"))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invoice_id       614 non-null    int64
#  1   customer_id      614 non-null    int64
#  2   invoice_date     614 non-null    datetime64[us]
#  3   billing_address  614 non-null    str
#  4   billing_city     614 non-null    str
#  5   billing_state    310 non-null    str
#  6   billing_country  614 non-null    str
#  7   billing_postal   559 non-null    str
#  8   total            614 non-null    float64
#  9   month_year       614 non-null    period[M]
# dtypes: datetime64[us](1), float64(1), int64(2), period[M](1), str(5)
# memory usage: 71.7 KB
